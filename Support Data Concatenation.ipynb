# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
water=pd.read_csv("Data/water_sources.csv")
waste=pd.read_csv("Data/waste_management.csv")
toilet=pd.read_csv("Data/toilets.csv")

# %%
water.dropna(inplace=True)

# %%
water.head()
# Out:
#    Year  Month       10u       10v       2d       2t     evabs     evaow  \
# 0  2019      1 -1.006850 -0.714544  293.502  297.417 -0.002489 -0.001031
# 1  2019      2 -1.408560 -0.662555  292.943  297.978 -0.002556 -0.001076
# 2  2019      3 -0.892110 -0.449448  293.250  297.989 -0.002535 -0.000980
# 3  2019      4 -0.392348  0.384925  293.934  296.542 -0.001748 -0.000658
# 4  2019      5 -0.447104  0.581028  292.571  294.726 -0.001374 -0.000462
#
#       evatc         evavt  ...        tp     swvl1     swvl2     swvl3  \
# 0 -0.000989 -3.445890e-08  ...  0.006655  0.346542  0.335724  0.264359
# 1 -0.000734 -3.818420e-08  ...  0.003201  0.254517  0.259918  0.281769
# 2 -0.000713 -3.678720e-08  ...  0.004682  0.278152  0.284195  0.261597
# 3 -0.001343 -2.700840e-08  ...  0.007518  0.385513  0.378616  0.309784
# 4 -0.001139 -2.048910e-08  ...  0.005989  0.397659  0.400055  0.392654
#
#       swvl4  Transformed_Latitude  Transformed_Longitude  Month_Year  \
# ...

# %%
waste.head()
# Out:
#    Year  Month       10u       10v       2d       2t     evabs     evaow  \
# 0  2019      1 -1.006850 -0.714544  293.502  297.417 -0.002489 -0.001031
# 1  2019      2 -1.408560 -0.662555  292.943  297.978 -0.002556 -0.001076
# 2  2019      3 -0.892110 -0.449448  293.250  297.989 -0.002535 -0.000980
# 3  2019      4 -0.392348  0.384925  293.934  296.542 -0.001748 -0.000658
# 4  2019      5 -0.447104  0.581028  292.571  294.726 -0.001374 -0.000462
#
#       evatc         evavt  ...        tp     swvl1     swvl2     swvl3  \
# 0 -0.000989 -3.445890e-08  ...  0.006655  0.346542  0.335724  0.264359
# 1 -0.000734 -3.818420e-08  ...  0.003201  0.254517  0.259918  0.281769
# 2 -0.000713 -3.678720e-08  ...  0.004682  0.278152  0.284195  0.261597
# 3 -0.001343 -2.700840e-08  ...  0.007518  0.385513  0.378616  0.309784
# 4 -0.001139 -2.048910e-08  ...  0.005989  0.397659  0.400055  0.392654
#
#       swvl4  Transformed_Latitude  Transformed_Longitude  Month_Year  \
# ...

# %%
toilet.head()
# Out:
#    Year  Month       10u       10v       2d       2t     evabs     evaow  \
# 0  2019      1 -1.006850 -0.714544  293.502  297.417 -0.002489 -0.001031
# 1  2019      2 -1.408560 -0.662555  292.943  297.978 -0.002556 -0.001076
# 2  2019      3 -0.892110 -0.449448  293.250  297.989 -0.002535 -0.000980
# 3  2019      4 -0.392348  0.384925  293.934  296.542 -0.001748 -0.000658
# 4  2019      5 -0.447104  0.581028  292.571  294.726 -0.001374 -0.000462
#
#       evatc         evavt  ...        tp     swvl1     swvl2     swvl3  \
# 0 -0.000989 -3.445890e-08  ...  0.006655  0.346542  0.335724  0.264359
# 1 -0.000734 -3.818420e-08  ...  0.003201  0.254517  0.259918  0.281769
# 2 -0.000713 -3.678720e-08  ...  0.004682  0.278152  0.284195  0.261597
# 3 -0.001343 -2.700840e-08  ...  0.007518  0.385513  0.378616  0.309784
# 4 -0.001139 -2.048910e-08  ...  0.005989  0.397659  0.400055  0.392654
#
#       swvl4  Transformed_Latitude  Transformed_Longitude  Month_Year  \
# ...

# %%
waste['dtype']='waste'
water['dtype']='water'
toilet['dtype']='toilet'

# %%
print("Waste Null Values",waste.shape)
print("Water Null Values",water.shape)
print("Toilet Null Values",toilet.shape)
# Out:
# Waste Null Values (5100, 44)
# Water Null Values (10500, 44)
# Toilet Null Values (10680, 44)

# %%
data=pd.concat([water,waste,toilet])

# %%
data.set_index('dtype',inplace=True)

# %%
data.shape
# Out:
# (26280, 43)

# %%
data=data.drop_duplicates()

# %%
data.head()
# Out:
#        Year  Month       10u       10v       2d       2t     evabs     evaow  \
# dtype
# water  2019      1 -1.006850 -0.714544  293.502  297.417 -0.002489 -0.001031
# water  2019      2 -1.408560 -0.662555  292.943  297.978 -0.002556 -0.001076
# water  2019      3 -0.892110 -0.449448  293.250  297.989 -0.002535 -0.000980
# water  2019      4 -0.392348  0.384925  293.934  296.542 -0.001748 -0.000658
# water  2019      5 -0.447104  0.581028  292.571  294.726 -0.001374 -0.000462
#
#           evatc         evavt  ...        tp     swvl1     swvl2     swvl3  \
# dtype                          ...
# water -0.000989 -3.445890e-08  ...  0.006655  0.346542  0.335724  0.264359
# water -0.000734 -3.818420e-08  ...  0.003201  0.254517  0.259918  0.281769
# water -0.000713 -3.678720e-08  ...  0.004682  0.278152  0.284195  0.261597
# water -0.001343 -2.700840e-08  ...  0.007518  0.385513  0.378616  0.309784
# water -0.001139 -2.048910e-08  ...  0.005989  0.397659  0.400055  0.392654
#
# ...

# %%
data.sort_values('Month_Year_lat_lon').head()
# Out:
#        Year  Month      10u       10v       2d      2t     evabs     evaow  \
# dtype
# water  2019     10 -1.00380 -0.087302  293.012  296.35 -0.001423 -0.000729
# waste  2019     10 -1.00380 -0.087302  293.012  296.35 -0.001423 -0.000729
# waste  2019     10 -1.00380 -0.087302  293.012  296.35 -0.001423 -0.000729
# water  2019     10 -1.00380 -0.087302  293.012  296.35 -0.001423 -0.000729
# water  2019     10 -1.25868  0.188577  292.946  296.09 -0.001478 -0.000975
#
#           evatc  evavt  ...        tp     swvl1     swvl2     swvl3     swvl4  \
# dtype                   ...
# water -0.001092    0.0  ...  0.006945  0.342346  0.314453  0.239990  0.216187
# waste -0.001092    0.0  ...  0.006945  0.342346  0.314453  0.239990  0.216187
# waste -0.001092    0.0  ...  0.006945  0.342346  0.314453  0.239990  0.216187
# water -0.001092    0.0  ...  0.006945  0.342346  0.314453  0.239990  0.216187
# water -0.000941    0.0  ...  0.006517  0.334244  0.313004  0.238129  0.236496
#
# ...
